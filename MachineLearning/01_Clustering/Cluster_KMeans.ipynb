# %%
import json
import pandas as pd
import re
import numpy as np
import nltk
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

# %% [markdown]
# #### Prepare preprocessing

# %%
#instantiate language specific stemmer: stemmer removes morphological affixes from words, leaving only the word stem
stemmer = SnowballStemmer('english')

#download stopwords
nltk.download("stopwords")

#select langueage specific stopwords and save in "words"
words = stopwords.words("english")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/hannah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# #### Load Real Data

# %%
#load json dataset 
json_file = 'Amazon_Electronics_2_cleaned.json'

#convert json string to pandas object and save it to data
data = pd.read_json(json_file, orient='records')

# %%
#show head of loaded data
data.head()
# Out:
#                             uniq_id            crawl_timestamp        asin  \
# 0  8258a459bf720ac86b8bc2d214346c35  2020-02-06 19:30:06 +0000  B07652FT69
# 1  8610899e786315b1adad872764f424b0  2020-02-07 00:20:04 +0000  B07TMCY7WN
# 2  1b0e4aa1d0cd635e2366558512ccc067  2020-02-06 19:59:39 +0000  B079VL519L
# 3  c5499856b11d3a2796bdd362b1701fc1  2020-02-07 02:38:59 +0000  B00JYKGFWY
# 4  ce5ac9f85505667fb9dafce9c1b0103c  2020-02-07 13:30:48 +0000  B07LB5SGK7
#
#                                          product_url  \
# 0  https://www.amazon.in/Cazcase-Pattern-Smart-Co...
# 1  https://www.amazon.in/D-kandy-Gionee-A1-Lite-M...
# 2  https://www.amazon.in/Heartly-Lenovo-A6600-Spi...
# 3  https://www.amazon.in/iPhone-LUVVITT%C2%AE-Scr...
# 4  https://www.amazon.in/Redgear-MPR800-Soft-Mous...
#
#                                         product_name  \
# 0  Cazcase Deer Pattern Smart Case Cover Flip Sta...
# 1  D-kandy for Gionee A1 Lite, Fashion Series Lea...
# 2  Heartly Kickstand Hard Dual Rugged Armor Hybri...
# 3  iPhone 6 Case, LUVVITT® ULTRA ARMOR iPhone 6 C...
# 4  Redgear MPR800 Soft Base Mousepad with 4 LED S...
#
#                                    image_urls__small  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
#
#                                               medium  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
# 2  https://images-na.ssl-images-amazon.com/images...
# 3  https://images-na.ssl-images-amazon.com/images...
# 4  https://images-na.ssl-images-amazon.com/images...
#
#                                                large  browsenode  \
# 0  https://images-na.ssl-images-amazon.com/images...  1375329031
# 1                                                NaN  1389409031
# 2  https://images-na.ssl-images-amazon.com/images...  1389409031
# 3  https://images-na.ssl-images-amazon.com/images...  1389409031
# 4  https://images-na.ssl-images-amazon.com/images...  1375413031
#
#                   seller_name  ... no__of_offers no__of_sellers  \
# 0             E Shop Solution  ...           NaN            NaN
# 1      SHIV DURGA ENTERPRISES  ...           NaN            NaN
# 2           Ruh International  ...           NaN            NaN
# 3                  HelloYehlo  ...           NaN            NaN
# 4  Appario Retail Private Ltd  ...           NaN            NaN
#
#    sales_rank_in_child_category product_details__k_v_pairs Number_Of_Items  \
# 0                           NaN                        NaN             NaN
# 1                           NaN                        NaN             NaN
# 2                           NaN                        NaN             NaN
# 3                           NaN                        NaN             NaN
# 4                           NaN                        NaN             NaN
#
#    Batteries_Included Batteries_Required Material Form_Factor left_in_stock
# 0                 NaN                NaN      NaN         NaN           NaN
# 1                 NaN                NaN      NaN         NaN           NaN
# 2                 NaN                NaN      NaN         NaN           NaN
# 3                 NaN                NaN      NaN         NaN           NaN
# 4                 NaN                NaN      NaN         NaN           NaN
#
# [5 rows x 36 columns]

# %%
#select relevant column and copy it into product_names
product_names = data[['product_name']].copy()

#show data
product_names.head()
# Out:
#                                         product_name
# 0  Cazcase Deer Pattern Smart Case Cover Flip Sta...
# 1  D-kandy for Gionee A1 Lite, Fashion Series Lea...
# 2  Heartly Kickstand Hard Dual Rugged Armor Hybri...
# 3  iPhone 6 Case, LUVVITT® ULTRA ARMOR iPhone 6 C...
# 4  Redgear MPR800 Soft Base Mousepad with 4 LED S...

# %% [markdown]
# #### Preprocessing

# %%
#preprocessing: apply stemming & lower case on each row of product_names. Save cleaned data in new column "cleaned"
product_names['cleaned'] = product_names['product_name'].apply(lambda x: " ".join([stemmer.stem(i) for i in re.sub("[^a-zA-Z]", " ", x).split() if i not in words]).lower())

#show cleaned data
product_names['cleaned'].head()
# Out:
# 0    cazcas deer pattern smart case cover flip stan...
# 1    d kandi gione a lite fashion seri leather flip...
# 2    heart kickstand hard dual rug armor hybrid bum...
# 3    iphon case luvvitt ultra armor iphon case best...
# 4     redgear mpr soft base mousepad led spectrum mode
# Name: cleaned, dtype: object

# %%
#vectorize cleaned text
vectorizer = TfidfVectorizer()
text_vec = vectorizer.fit_transform(product_names['cleaned'])

#show size of cleaned text
text_vec.shape
# Out:
# (10000, 7598)

# %% [markdown]
# #### K-Means Algorithm: 1. Iteration

# %%
#apply KMeans: select number of clusters 
kmeans = KMeans(n_clusters=30, random_state=0).fit(text_vec)

# %% [markdown]
# #### Add the clusters to the data

# %%
#add clusters to original data
product_names['clusters'] = kmeans.labels_

# %%
#show product_names to see added clusters column
product_names.head()
# Out:
#                                         product_name  \
# 0  Cazcase Deer Pattern Smart Case Cover Flip Sta...
# 1  D-kandy for Gionee A1 Lite, Fashion Series Lea...
# 2  Heartly Kickstand Hard Dual Rugged Armor Hybri...
# 3  iPhone 6 Case, LUVVITT® ULTRA ARMOR iPhone 6 C...
# 4  Redgear MPR800 Soft Base Mousepad with 4 LED S...
#
#                                              cleaned  clusters
# 0  cazcas deer pattern smart case cover flip stan...        12
# 1  d kandi gione a lite fashion seri leather flip...        26
# 2  heart kickstand hard dual rug armor hybrid bum...         3
# 3  iphon case luvvitt ultra armor iphon case best...        10
# 4   redgear mpr soft base mousepad led spectrum mode         7

# %%
#get number of items per cluster
product_names.groupby(by=["clusters"]).size()
# Out:
# clusters
# 0      229
# 1      352
# 2      227
# 3      244
# 4      630
# 5      128
# 6      153
# 7     2042
# 8       94
# 9      375
# 10     505
# 11     232
# 12     168
# 13     445
# 14     493
# 15     187
# 16     173
# 17     399
# 18     237
# 19     211
# 20     117
# 21      76
# 22     113
# 23     232
# 24     227
# 25     209
# 26     565
# 27     439
# 28     157
# 29     341
# dtype: int64

# %%
#check results for cluster 1
product_names[product_names['clusters']==1]['product_name']
# Out:
# 19      Nainika Cute Girlish Soft Silicone Meow Cat Ea...
# 24      Mobyro Kitty Case Cover for- Motorola G4 Plus ...
# 50      ANVIKA 3D Cute Rubber Hello Kitty Back Case Co...
# 67      YES2GOOD Redmi 4A Kitty Case Cover | Soft TPU ...
# 100     YES2GOOD Soft Silicone Printed Rubber Back Cov...
#                               ...
# 9914    Mobyro Galaxy C9 PRO Hello Kitty Cover Case Cu...
# 9961    Nainika Cute Girlish Soft Silicone Meow Cat Ea...
# 9983    Mobyro Cute Cartoon Hello Kitty Case Cover for...
# 9989    Avianna 3D Cute Hello Kitty Back Cover for Hon...
# 9990    ANVIKA Soft Silicone Rubber Hello Kitty Cover ...
# Name: product_name, Length: 352, dtype: object

# %%
#add clusters to original data
result_df = pd.merge(data, product_names[['product_name','clusters']], how='inner', on=["product_name"])

# %%
result_df[result_df.duplicated(subset=['product_url'])]
# Out:
#                                uniq_id            crawl_timestamp        asin  \
# 11    3e46c10d86062e9f9b9a828b22cbfe57  2020-02-07 00:51:50 +0000  B07BV5K9TV
# 13    72de8eea88eca5d131ae48a04c82147e  2020-02-07 00:51:02 +0000  B07BTS9NSX
# 66    f0525fde1a95b50620339b79964b89c5  2020-02-06 21:18:36 +0000  B01MZB41X2
# 68    e4e7783f08d99d348b02d13588eb0c69  2020-02-06 21:30:34 +0000  B01EDYG1J2
# 159   4f8b85f170a78a25f235951b36525991  2020-02-07 09:32:04 +0000  B07MTDV44F
# ...                                ...                        ...         ...
# 7983  261e915c38c29da72094fce678f8bee8  2020-02-07 01:48:18 +0000  B07VVNZ6KF
# 8080  f3cfab1de7cc888e7420d91de735f19a  2020-02-06 23:30:20 +0000  B07TCK5JDB
# 8082  c976542cae225e4eabee192f377e5472  2020-02-06 23:24:48 +0000  B07T9HKN34
# 8670  80ce552ea93eb406c2c9142289a8cd1f  2020-02-07 09:05:59 +0000  B07X48F1FS
# 8672  d5aa99e6a3b63ff5e73fdc977b6469a7  2020-02-07 09:05:38 +0000  B07X48WK25
#
#                                             product_url  \
# 11    https://www.amazon.in/Aarfa-Slimfit-Durable-Pr...
# 13    https://www.amazon.in/Aarfa-Slimfit-Durable-Pr...
# 66    https://www.amazon.in/SCHOFIC-Premium-Leather-...
# 68    https://www.amazon.in/SCHOFIC-Premium-Leather-...
# 159   https://www.amazon.in/Taiaiping-Double-Layer-C...
# ...                                                 ...
# 7983  https://www.amazon.in/Shree-Krishnam-Enterpris...
# 8080  https://www.amazon.in/BuyFeb%C2%AE-Printed-Com...
# 8082  https://www.amazon.in/BuyFeb%C2%AE-Printed-Com...
# 8670  https://www.amazon.in/Shree-Krishnam-Enterpris...
# 8672  https://www.amazon.in/Shree-Krishnam-Enterpris...
#
#                                            product_name  \
# 11    Aarfa Slimfit Durable Printed Hard Case for Xi...
# 13    Aarfa Slimfit Durable Printed Hard Case for Xi...
# 66    SCHOFIC Fancy Wallet Diary Faux Leather Mobile...
# 68    SCHOFIC Fancy Wallet Diary Faux Leather Mobile...
# 159   Taiaiping Armor Series Perfectly Fits The Sams...
# ...                                                 ...
# 7983  Shree Krishnam Enterprises Back Cover for Oppo...
# 8080  BuyFeb® Printed Soft Back Cover Case Compatibl...
# 8082  BuyFeb® Printed Soft Back Cover Case Compatibl...
# 8670  Shree Krishnam Enterprises vivo s1 Back Cover,...
# 8672  Shree Krishnam Enterprises vivo s1 Back Cover,...
#
#                                       image_urls__small  \
# 11    https://images-na.ssl-images-amazon.com/images...
# 13    https://images-na.ssl-images-amazon.com/images...
# 66    https://images-na.ssl-images-amazon.com/images...
# 68    https://images-na.ssl-images-amazon.com/images...
# 159   https://images-na.ssl-images-amazon.com/images...
# ...                                                 ...
# 7983  https://images-na.ssl-images-amazon.com/images...
# 8080  https://images-na.ssl-images-amazon.com/images...
# 8082  https://images-na.ssl-images-amazon.com/images...
# 8670  https://images-na.ssl-images-amazon.com/images...
# 8672  https://images-na.ssl-images-amazon.com/images...
#
#                                                  medium  \
# 11    https://images-na.ssl-images-amazon.com/images...
# 13    https://images-na.ssl-images-amazon.com/images...
# 66    https://images-na.ssl-images-amazon.com/images...
# 68    https://images-na.ssl-images-amazon.com/images...
# 159   https://images-na.ssl-images-amazon.com/images...
# ...                                                 ...
# 7983  https://images-na.ssl-images-amazon.com/images...
# 8080  https://images-na.ssl-images-amazon.com/images...
# 8082  https://images-na.ssl-images-amazon.com/images...
# 8670  https://images-na.ssl-images-amazon.com/images...
# 8672  https://images-na.ssl-images-amazon.com/images...
#
#                                                   large  browsenode  \
# 11    https://images-na.ssl-images-amazon.com/images...  1389409031
# 13    https://images-na.ssl-images-amazon.com/images...  1389409031
# 66    https://images-na.ssl-images-amazon.com/images...  1389409031
# 68    https://images-na.ssl-images-amazon.com/images...  1389409031
# 159   https://images-na.ssl-images-amazon.com/images...  1389409031
# ...                                                 ...         ...
# 7983  https://images-na.ssl-images-amazon.com/images...  1389409031
# 8080                                                NaN  1389409031
# 8082                                                NaN  1389409031
# 8670                                                NaN  1389409031
# 8672                                                NaN  1389409031
#
#                 seller_name  ... no__of_sellers sales_rank_in_child_category  \
# 11                 arretail  ...            NaN                          NaN
# 13                 arretail  ...            NaN                          NaN
# 66                  Schofic  ...            NaN                          NaN
# 68                  Schofic  ...            NaN                          NaN
# 159            SSA infotech  ...            NaN                          NaN
# ...                     ...  ...            ...                          ...
# 7983  KRISHNAM ENTERPRISESs  ...            NaN                          NaN
# 8080             BuyFeb com  ...            NaN                          NaN
# 8082             BuyFeb com  ...            NaN                          NaN
# 8670  KRISHNAM ENTERPRISESs  ...            NaN                          NaN
# 8672  KRISHNAM ENTERPRISESs  ...            NaN                          NaN
#
#       product_details__k_v_pairs Number_Of_Items Batteries_Included  \
# 11                           NaN             NaN                NaN
# 13                           NaN             NaN                NaN
# 66                           NaN             NaN                NaN
# 68                           NaN             NaN                NaN
# 159                          NaN             NaN                NaN
# ...                          ...             ...                ...
# 7983                         NaN             NaN                NaN
# 8080                         NaN             NaN                NaN
# 8082                         NaN             NaN                NaN
# 8670                         NaN             NaN                NaN
# 8672                         NaN             NaN                NaN
#
#       Batteries_Required Material Form_Factor left_in_stock clusters
# 11                   NaN      NaN         NaN           NaN       17
# 13                   NaN      NaN         NaN           NaN       17
# 66                   NaN      NaN         NaN           NaN        6
# 68                   NaN      NaN         NaN           NaN        6
# 159                  NaN      NaN         NaN           NaN        4
# ...                  ...      ...         ...           ...      ...
# 7983                 NaN      NaN         NaN           NaN        2
# 8080                 NaN      NaN         NaN           NaN       15
# 8082                 NaN      NaN         NaN           NaN       15
# 8670                 NaN      NaN         NaN           NaN       15
# 8672                 NaN      NaN         NaN           NaN       15
#
# [280 rows x 37 columns]

# %%
#drop duplicates
result_df.drop_duplicates(subset=['product_url'],inplace=True)
result_df.shape
# Out:
# (10000, 37)

# %%
#sort values by clusters
result_df.sort_values(by=['clusters'],inplace=True)
result_df.head()
# Out:
#                                uniq_id            crawl_timestamp        asin  \
# 8919  9a37ef174752e4e7775c39fbd50c7521  2020-02-06 19:42:56 +0000  B079H4VBPD
# 2143  b78555440d8ed04ad8748bae96ff0ee7  2020-02-06 23:13:03 +0000  B0169EN22I
# 1690  aca76bb28865832c26a25fb6cd42155c  2020-02-06 20:59:05 +0000  B01N9OL91B
# 707   f1157809aeb50d198cdc3e36ee320da3  2020-02-06 23:03:43 +0000  B01KZNRM0W
# 9795  c26dabcdc08233aa944cd5c8ce95140e  2020-02-07 09:34:56 +0000  B07GB6XTNF
#
#                                             product_url  \
# 8919  https://www.amazon.in/Tech-Tempered-Screen-Pro...
# 2143  https://www.amazon.in/Skinomi-TechSkin-Surface...
# 1690  https://www.amazon.in/Moshi-Anti-Glare-Protect...
# 707   https://www.amazon.in/RBEIK-iPad-Screen-Protec...
# 9795  https://www.amazon.in/i-Blason-Full-Body-Glitt...
#
#                                            product_name  \
# 8919  M Tech Redmi Note 4 Red & Tempered Glass Scree...
# 2143  Skinomi TechSkin - Surface Pro 4 Screen Protec...
# 1690  Moshi iVisor Anti-Glare Screen Protector Compa...
# 707   RBEIK iPad Pro 12.9 Screen Protector Glass - P...
# 9795  Samsung Galaxy Note 9 Case, i-Blason [Cosmo] F...
#
#                                       image_urls__small  \
# 8919  https://images-na.ssl-images-amazon.com/images...
# 2143  https://images-na.ssl-images-amazon.com/images...
# 1690  https://images-na.ssl-images-amazon.com/images...
# 707   https://images-na.ssl-images-amazon.com/images...
# 9795  https://images-na.ssl-images-amazon.com/images...
#
#                                                  medium  \
# 8919  https://images-na.ssl-images-amazon.com/images...
# 2143  https://images-na.ssl-images-amazon.com/images...
# 1690  https://images-na.ssl-images-amazon.com/images...
# 707   https://images-na.ssl-images-amazon.com/images...
# 9795  https://images-na.ssl-images-amazon.com/images...
#
#                                                   large  browsenode  \
# 8919  https://images-na.ssl-images-amazon.com/images...  1389403031
# 2143  https://images-na.ssl-images-amazon.com/images...  1375332031
# 1690  https://images-na.ssl-images-amazon.com/images...  1375317031
# 707   https://images-na.ssl-images-amazon.com/images...  1375332031
# 9795  https://images-na.ssl-images-amazon.com/images...  1389409031
#
#              seller_name  ... no__of_sellers sales_rank_in_child_category  \
# 8919  M Tech enterprises  ...            NaN                          NaN
# 2143                 NaN  ...            NaN                          NaN
# 1690                 NaN  ...            NaN                          NaN
# 707       Cart2India SLP  ...            NaN                          NaN
# 9795     Expo Associates  ...            NaN                          NaN
#
#       product_details__k_v_pairs Number_Of_Items Batteries_Included  \
# 8919                         NaN             NaN                NaN
# 2143                         NaN             NaN                NaN
# 1690                         NaN             NaN                NaN
# 707                          NaN             NaN                NaN
# 9795                         NaN             NaN                NaN
#
#       Batteries_Required Material Form_Factor left_in_stock clusters
# 8919                 NaN      NaN         NaN           NaN        0
# 2143                 NaN      NaN         NaN           NaN        0
# 1690                 NaN      NaN         NaN           NaN        0
# 707                  NaN      NaN         NaN           NaN        0
# 9795                 NaN      NaN         NaN           NaN        0
#
# [5 rows x 37 columns]

# %% [markdown]
# #### Generate sample dataset from the clusters

# %%
#get random 20 products from each cluster
sample_dataset2=result_df.groupby("clusters").sample(n=20, random_state=1)

# %%
sample_dataset2.head()
# Out:
#                                uniq_id            crawl_timestamp        asin  \
# 4754  754f992887816c11dc6433ee0ac2d2f6  2020-02-06 20:57:26 +0000  B00HSGR7R8
# 3831  fdf046641c7db85afb30fcd584b8598e  2020-02-07 01:11:51 +0000  B01AA5SFK6
# 5915  590ff6c0e11619ab417f7650a8e75b8c  2020-02-06 17:16:37 +0000  B0792DNLB7
# 262   980ab756824fb4f7707e9fe3af625687  2020-02-07 01:06:03 +0000  B077JJWBN9
# 8704  4a096644c1886970d9b5f0915ff12cea  2020-02-06 19:26:37 +0000  B00SA0BAEW
#
#                                             product_url  \
# 4754  https://www.amazon.in/LENTION-Anti-scratch-Hyd...
# 3831  https://www.amazon.in/EEEKit-Premium-Tempered-...
# 5915  https://www.amazon.in/Nillkin-Tempered-Amazing...
# 262   https://www.amazon.in/Supershieldz-Kurio-Next-...
# 8704  https://www.amazon.in/Stony-Edge-Protector-Pol...
#
#                                            product_name  \
# 4754  LENTION Clear Screen Protector for 13-inch Mac...
# 3831  EEEKit HD Tempered Glass Screen Protector Film...
# 5915  Nillkin Tempered Glass Amazing H Anti-Explosio...
# 262   [3-Pack] Supershieldz for Kurio Next 7  Kids T...
# 8704  Stony-Edge iPhone 6 Wallet Case, Flip & Stand ...
#
#                                       image_urls__small  \
# 4754  https://images-na.ssl-images-amazon.com/images...
# 3831  https://images-na.ssl-images-amazon.com/images...
# 5915  https://images-na.ssl-images-amazon.com/images...
# 262   https://images-na.ssl-images-amazon.com/images...
# 8704  https://images-na.ssl-images-amazon.com/images...
#
#                                                  medium  \
# 4754  https://images-na.ssl-images-amazon.com/images...
# 3831  https://images-na.ssl-images-amazon.com/images...
# 5915  https://images-na.ssl-images-amazon.com/images...
# 262   https://images-na.ssl-images-amazon.com/images...
# 8704  https://images-na.ssl-images-amazon.com/images...
#
#                                                   large  browsenode  \
# 4754  https://images-na.ssl-images-amazon.com/images...  1375317031
# 3831  https://images-na.ssl-images-amazon.com/images...  1375332031
# 5915  https://images-na.ssl-images-amazon.com/images...  1389409031
# 262                                                 NaN  1375332031
# 8704                                                NaN  1389403031
#
#              seller_name  ... no__of_sellers sales_rank_in_child_category  \
# 4754                 NaN  ...            NaN                          NaN
# 3831      Cart2India SLP  ...            NaN                          NaN
# 5915               HiGAR  ...            NaN                          NaN
# 262    Cart2India Online  ...            NaN                          NaN
# 8704  Yuva Fashion Store  ...            NaN                          NaN
#
#       product_details__k_v_pairs Number_Of_Items Batteries_Included  \
# 4754                         NaN             NaN                NaN
# 3831                         NaN             NaN                NaN
# 5915                         NaN             NaN                NaN
# 262                          NaN             NaN                NaN
# 8704                         NaN             NaN                NaN
#
#       Batteries_Required Material Form_Factor left_in_stock clusters
# 4754                 NaN      NaN         NaN           NaN        0
# 3831                 NaN      NaN         NaN           NaN        0
# 5915                 NaN      NaN         NaN           NaN        0
# 262                  NaN      NaN         NaN           NaN        0
# 8704                 NaN      NaN         NaN           NaN        0
#
# [5 rows x 37 columns]

# %%
#save file with all clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df.iterrows()],indent=4)

with open('products_with_cluster.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save test/training data as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sample_dataset2.iterrows()],indent=4)

with open('sampledata_cluster.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save file with all clusters as CSV
file_name = 'products_with_cluster.csv'
result_df.to_csv(file_name,header=True)

# %%
#save test/training data as CSV
file_name = 'sampledata_cluster.csv'
sample_dataset2.to_csv(file_name,header=True)

# %%
#Assigning clusters to product types according to the cluster analysis 
screen_protectors = result_df[result_df['clusters']==0]
flip_covers = result_df[result_df['clusters']==6]
headphones = result_df[result_df['clusters']==9]
ipad_covers = result_df[result_df['clusters']==12]
cables = result_df[result_df['clusters']==23]
hdmi_cables = result_df[result_df['clusters']==24]
kickstand_covers = result_df[result_df['clusters']==3]
mouse_mousepad = result_df[result_df['clusters']==18]
mobile_covers = result_df[result_df['clusters'].isin([1,2,4,5,8,10,11,14,15,17,19,20,21,22,25,26,27,28,29])]

# %%
#get random 50 from each product category (change variable before .sample and name of json-file depending on category)
sampledata = screen_protectors.sample(n=50, random_state=1)

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('screen_protectors_sample3.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==0].iterrows()],indent=4)

with open('screen_protectors.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==6].iterrows()],indent=4)

with open('flip_covers.json', 'w') as outfile:
    outfile.write(json_object) 

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==9].iterrows()],indent=4)

with open('headphones.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in mouse_mousepad.iterrows()],indent=4)

with open('mouse_mousepad.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==12].iterrows()],indent=4)

with open('ipad_covers.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==23].iterrows()],indent=4)

with open('cables.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==24].iterrows()],indent=4)

with open('hdmi_cables.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==3].iterrows()],indent=4)

with open('kickstand_covers.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters']==6].iterrows()],indent=4)

with open('flip_covers.json', 'w') as outfile:
    outfile.write(json_object) 
    
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in result_df[result_df['clusters'].isin([1,2,4,5,8,10,11,14,15,17,19,20,21,22,25,26,27,28,29])].iterrows()],indent=4)

with open('mobile_covers.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#second iteration cluster 7

#vectorize cleaned text
vectorizer2 = TfidfVectorizer()
cluster7 = product_names[product_names['clusters']==7]
text_vec2 = vectorizer2.fit_transform(cluster7['cleaned'])

#show size of cleaned text
text_vec2.shape

#apply KMeans: select number of clusters 
kmeans2 = KMeans(n_clusters=30, random_state=0).fit(text_vec2)

#add clusters to original data
cluster7['cluster'] = kmeans2.labels_

#show product_names to see added clusters column
cluster7.head()
# Out:
# <ipython-input-284-43091b0c8355>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster7['cluster'] = kmeans2.labels_
#                                          product_name  \
# 4   Redgear MPR800 Soft Base Mousepad with 4 LED S...
# 5   RAYOVAC 815-60PPF Alkaline Batteries Reclosabl...
# 6   Aimo Wireless IPH5PCLP002 Rubber Essentials Sl...
# 8   Generic MC0001 Cell Phone Case for iPhone 4 - ...
# 22  LuMee Two for iPhone 8/7/6s/6, The and Authent...
#
#                                               cleaned  clusters  cluster
# 4    redgear mpr soft base mousepad led spectrum mode         7        0
# 5   rayovac ppf alkalin batteri reclos pro pack aa pk         7        1
# 6   aimo wireless iph pclp rubber essenti slim dur...         7       11
# 8   generic mc cell phone case iphon non retail pa...         7       11
# 22  lume two iphon the authent patent protect self...         7        0

# %%
cluster7.groupby(by=["cluster"]).size()
# Out:
# cluster
# 0     497
# 1     100
# 2      95
# 3     120
# 4      83
# 5      62
# 6      37
# 7      29
# 8      24
# 9      19
# 10     67
# 11     68
# 12     16
# 13     31
# 14     94
# 15     47
# 16     94
# 17     15
# 18     50
# 19     24
# 20     97
# 21     36
# 22     67
# 23     80
# 24     42
# 25     44
# 26     13
# 27     41
# 28     26
# 29     24
# dtype: int64

# %%
#add clusters to original data
result_df2 = pd.merge(data, cluster7[['product_name','cluster']], how='inner', on=["product_name"])

result_df2[result_df2.duplicated(subset=['product_url'])]

#drop duplicates
result_df2.drop_duplicates(subset=['product_url'],inplace=True)
result_df2.shape

#sort values by clusters
result_df2.sort_values(by=['cluster'],inplace=True)
result_df2.head()
# Out:
#                               uniq_id            crawl_timestamp        asin  \
# 0    ce5ac9f85505667fb9dafce9c1b0103c  2020-02-07 13:30:48 +0000  B07LB5SGK7
# 953  b6f226b239a591b84ac8e9306195d624  2020-02-06 18:14:09 +0000  B0078P5V2C
# 955  e22dfd0515b1d570f20f797792ea877b  2020-02-07 00:16:52 +0000  B079HCNWB6
# 957  db0abf073e981b2e7f7435bec6d8a7e7  2020-02-07 11:35:53 +0000  B001TLMRW8
# 959  2e54b997fa3044ddc77ebe33afbb1c53  2020-02-07 06:33:59 +0000  B074QYMFZC
#
#                                            product_url  \
# 0    https://www.amazon.in/Redgear-MPR800-Soft-Mous...
# 953  https://www.amazon.in/NP-BN1-Replacement-Batte...
# 955  https://www.amazon.in/Buckle-Down-Cell-Phone-S...
# 957  https://www.amazon.in/Krusell-Mobile-Pouch-952...
# 959  https://www.amazon.in/Stinger-Select-SSPRCA6-P...
#
#                                           product_name  \
# 0    Redgear MPR800 Soft Base Mousepad with 4 LED S...
# 953  Pack of 2 NP-BN1 Batteries for Sony Cyber-Shot...
# 955  Buckle-Down Cell Phone Case for Samsung Galaxy...
# 957  Krusell Luna Mobile Pouch 95212 Universal Larg...
# 959  Stinger Select SSPRCA6 Performance Series 6' C...
#
#                                      image_urls__small  \
# 0    https://images-na.ssl-images-amazon.com/images...
# 953  https://images-na.ssl-images-amazon.com/images...
# 955  https://images-na.ssl-images-amazon.com/images...
# 957  https://images-na.ssl-images-amazon.com/images...
# 959  https://images-na.ssl-images-amazon.com/images...
#
#                                                 medium  \
# 0    https://images-na.ssl-images-amazon.com/images...
# 953  https://images-na.ssl-images-amazon.com/images...
# 955  https://images-na.ssl-images-amazon.com/images...
# 957  https://images-na.ssl-images-amazon.com/images...
# 959  https://images-na.ssl-images-amazon.com/images...
#
#                                                  large  browsenode  \
# 0    https://images-na.ssl-images-amazon.com/images...  1375413031
# 953  https://images-na.ssl-images-amazon.com/images...  1388983031
# 955  https://images-na.ssl-images-amazon.com/images...  1389409031
# 957  https://images-na.ssl-images-amazon.com/images...  1389409031
# 959  https://images-na.ssl-images-amazon.com/images...  1389231031
#
#                     seller_name  ... no__of_sellers  \
# 0    Appario Retail Private Ltd  ...            NaN
# 953                         NaN  ...            NaN
# 955                         NaN  ...            NaN
# 957                   Trumpcard  ...            NaN
# 959               Buy Your Wish  ...            NaN
#
#     sales_rank_in_child_category  product_details__k_v_pairs Number_Of_Items  \
# 0                            NaN                         NaN             NaN
# 953                          NaN                         NaN             NaN
# 955                          NaN                         NaN             NaN
# 957                          NaN                         NaN             NaN
# 959                          NaN                         NaN             NaN
#
#     Batteries_Included  Batteries_Required Material Form_Factor left_in_stock  \
# 0                  NaN                 NaN      NaN         NaN           NaN
# 953                NaN                 NaN      NaN         NaN           NaN
# 955                NaN                 NaN      NaN         NaN           NaN
# 957                NaN                 NaN      NaN         NaN           NaN
# 959                NaN                 NaN      NaN         NaN           NaN
#
#     cluster
# 0         0
# 953       0
# 955       0
# 957       0
# 959       0
#
# [5 rows x 37 columns]

# %%
#get random 20 products from each cluster
sample_dataset_cluster7=result_df2.groupby("cluster").sample(n=20, random_state=1)

#save test/training data as json
json_object2 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster7.iterrows()],indent=4)

with open('sampledata_cluster7.json', 'w') as outfile:
    outfile.write(json_object2)

# %%
#Assigning clusters to product types according to the cluster analysis 
mobile_covers2 = result_df2[result_df2['cluster'].isin([2,11,17,21,23,27])]
batteries = result_df2[result_df2['cluster']==1]
camera_accessories = result_df2[result_df2['cluster'].isin([4,19,20])]
macbook_accessories = result_df2[result_df2['cluster']==5]
tv_accessories = result_df2[result_df2['cluster'].isin([6,12])]
keyboard_cases_tablets = result_df2[result_df2['cluster']==7]
memory_cards = result_df2[result_df2['cluster'].isin([8,24])]
nikon_batteries = result_df2[result_df2['cluster']==9]
car_phone_chargers = result_df2[result_df2['cluster']==10]
tv_covers = result_df2[result_df2['cluster']==12]
car_phone_holder = result_df2[result_df2['cluster'].isin([13,14])]
airpod_cases = result_df2[result_df2['cluster']==15]
back_covers = result_df2[result_df2['cluster'].isin([16,26])]
keyboards_and_accessories = result_df2[result_df2['cluster']==18]
headphones2 = result_df2[result_df2['cluster']==22]
glasses = result_df2[result_df2['cluster']==25]
dvds = result_df2[result_df2['cluster']==28]
laptop_tables = result_df2[result_df2['cluster']==29]

# %%
#get random data from each product category (change variable before .sample and name of json-file depending on category)
sampledata = tv_accessories.sample(n=53, random_state=1)

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('tv_accessories_sample.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in mobile_covers2.iterrows()],indent=4)

with open('mobile_covers2.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in batteries.iterrows()],indent=4)

with open('batteries.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in camera_accessories.iterrows()],indent=4)

with open('camera_accessories.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in macbook_accessories.iterrows()],indent=4)

with open('macbook_accessories.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in tv_mounts.iterrows()],indent=4)

with open('tv_mounts.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in memory_cards.iterrows()],indent=4)

with open('memory_cards.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in keyboard_cases_tablets.iterrows()],indent=4)

with open('keyboard_cases_tablets.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in nikon_batteries.iterrows()],indent=4)

with open('nikon_batteries.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in car_phone_chargers.iterrows()],indent=4)
    
with open('car_phone_chargers.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in tv_covers.iterrows()],indent=4)

with open('tv_covers.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in car_phone_holder.iterrows()],indent=4)

with open('car_phone_holder.json', 'w') as outfile:
    outfile.write(json_object)   
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in airpod_cases.iterrows()],indent=4)

with open('airpod_cases.json', 'w') as outfile:
    outfile.write(json_object)   
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in back_covers.iterrows()],indent=4)

with open('back_covers.json', 'w') as outfile:
    outfile.write(json_object)      

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in keyboards_and_accessories.iterrows()],indent=4)

with open('keyboards_and_accessories.json', 'w') as outfile:
    outfile.write(json_object)      
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in headphones2.iterrows()],indent=4)

with open('headphones2.json', 'w') as outfile:
    outfile.write(json_object)      

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in glasses.iterrows()],indent=4)

with open('glasses.json', 'w') as outfile:
    outfile.write(json_object)    
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in dvds.iterrows()],indent=4)

with open('dvds.json', 'w') as outfile:
    outfile.write(json_object)     

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_tables.iterrows()],indent=4)

with open('laptop_tables.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#second iteration cluster 13

#vectorize cleaned text
vectorizer2 = TfidfVectorizer()
cluster13 = product_names[product_names['clusters']==13]
text_vec2 = vectorizer2.fit_transform(cluster13['cleaned'])

#show size of cleaned text
text_vec2.shape

#apply KMeans: select number of clusters 
kmeans2 = KMeans(n_clusters=10, random_state=0).fit(text_vec2)

#add clusters to original data
cluster13['cluster'] = kmeans2.labels_


#show product_names to see added clusters column
cluster13.head()
# Out:
# <ipython-input-120-b701f292d5b9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster13['cluster'] = kmeans2.labels_
#                                          product_name  \
# 12  Saco Transparent Laptop Touchpad Protector for...
# 30  Tomtoc 360 Protective Sleeve Case for Apple 15...
# 40  ProCase 14-15.6 Inch Laptop Sleeve Case Protec...
# 69  MOCA Anti-theft Lightweight [RollTop] Design M...
# 73  LeeRooy Blue 2 Big Part Tourister Laptop Backp...
#
#                                               cleaned  clusters  cluster
# 12  saco transpar laptop touchpad protector all la...        13        2
# 30  tomtoc protect sleev case appl inch new macboo...        13        9
# 40  procas inch laptop sleev case protect bag macb...        13        9
# 69  moca anti theft lightweight rolltop design men...        13        7
# 73  leerooy blue big part tourist laptop backpack ...        13        7

# %%
cluster13.groupby(by=["cluster"]).size()
# Out:
# cluster
# 0    40
# 1    33
# 2    27
# 3    52
# 4    34
# 5    26
# 6    31
# 7    90
# 8    72
# 9    40
# dtype: int64

# %%
#add clusters to original data
result_df2 = pd.merge(data, cluster13[['product_name','cluster']], how='inner', on=["product_name"])

result_df2[result_df2.duplicated(subset=['product_url'])]

#drop duplicates
result_df2.drop_duplicates(subset=['product_url'],inplace=True)
result_df2.shape

#sort values by clusters
result_df2.sort_values(by=['cluster'],inplace=True)
result_df2.head()
# Out:
#                               uniq_id            crawl_timestamp        asin  \
# 198  2cbfdf2b255be387e550b128ca977609  2020-02-07 06:27:12 +0000  B0743FP5XH
# 155  07f75096e36cec1fe251db899b7497b3  2020-02-06 20:45:26 +0000  B07BCHJGL5
# 265  65844781f1b4c3275326e38cb3fb5070  2020-02-06 20:51:10 +0000  B016QJHG7S
# 63   99a6cca52a8a563f6c866cb7f318de77  2020-02-06 20:40:11 +0000  B01N8UW906
# 401  4e9b685739c1209633b216f3f6cd6a74  2020-02-07 02:11:15 +0000  B07CZ176QQ
#
#                                            product_url  \
# 198  https://www.amazon.in/Emartbuy%C2%AE-Resistant...
# 155  https://www.amazon.in/Emartbuy%C2%AE-Resistant...
# 265  https://www.amazon.in/Universal-Music-Premium-...
# 63   https://www.amazon.in/Protecta-Laptop-Sleeve-L...
# 401  https://www.amazon.in/Business-Briefcase-Beaut...
#
#                                           product_name  \
# 198  Emartbuy Laptop Neoprene Sleeve case with Zip ...
# 155  Emartbuy Laptop Neoprene Sleeve case with Zip ...
# 265  Universal Music Premium Laptop Sleeve for 13 I...
# 63   Protecta Plain Jane Laptop Sleeve for Laptops ...
# 401  Business Briefcase Sleeve Beautiful Colorful O...
#
#                                      image_urls__small  \
# 198  https://images-na.ssl-images-amazon.com/images...
# 155  https://images-na.ssl-images-amazon.com/images...
# 265  https://images-na.ssl-images-amazon.com/images...
# 63   https://images-na.ssl-images-amazon.com/images...
# 401  https://images-na.ssl-images-amazon.com/images...
#
#                                                 medium  \
# 198  https://images-na.ssl-images-amazon.com/images...
# 155  https://images-na.ssl-images-amazon.com/images...
# 265  https://images-na.ssl-images-amazon.com/images...
# 63   https://images-na.ssl-images-amazon.com/images...
# 401  https://images-na.ssl-images-amazon.com/images...
#
#                                                  large  browsenode  \
# 198  https://images-na.ssl-images-amazon.com/images...  1375329031
# 155  https://images-na.ssl-images-amazon.com/images...  1375468031
# 265  https://images-na.ssl-images-amazon.com/images...  1375468031
# 63   https://images-na.ssl-images-amazon.com/images...  1375468031
# 401  https://images-na.ssl-images-amazon.com/images...  1375468031
#
#                     seller_name  ... no__of_sellers  \
# 198               EmartbuyIndia  ...            NaN
# 155               EmartbuyIndia  ...            NaN
# 265  Electrical & Musical Deals  ...            NaN
# 63                     Protecta  ...            NaN
# 401              Torque Traders  ...            NaN
#
#     sales_rank_in_child_category  product_details__k_v_pairs Number_Of_Items  \
# 198                          NaN                         NaN             NaN
# 155                          NaN                         NaN             NaN
# 265                          NaN                         NaN             NaN
# 63                           NaN                         NaN             NaN
# 401                          NaN                         NaN             NaN
#
#     Batteries_Included  Batteries_Required Material Form_Factor left_in_stock  \
# 198                NaN                 NaN      NaN         NaN           NaN
# 155                NaN                 NaN      NaN         NaN           NaN
# 265                NaN                 NaN      NaN         NaN           NaN
# 63                 NaN                 NaN      NaN         NaN           NaN
# 401                NaN                 NaN      NaN         NaN           NaN
#
#     cluster
# 198       0
# 155       0
# 265       0
# 63        0
# 401       0
#
# [5 rows x 37 columns]

# %%
#get random 20 products from each cluster
sample_dataset_cluster13=result_df2.groupby("cluster").sample(n=20, random_state=1)

#save test/training data as json
json_object2 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster7.iterrows()],indent=4)

with open('sampledata_cluster13.json', 'w') as outfile:
    outfile.write(json_object2)

# %%
#Assigning clusters to product types according to the cluster analysis 
laptop_sleeves_cases = result_df2[result_df2['cluster'].isin([0,9])]
laptop_backpacks = result_df2[result_df2['cluster'].isin([1,7])]
keyboard_protectors = result_df2[result_df2['cluster'].isin([2,6])]
laptop_bags = result_df2[result_df2['cluster']==3]
laptop_adapters_chargers = result_df2[result_df2['cluster']==4]
laptop_batteries = result_df2[result_df2['cluster']==5]
laptop_stickers = result_df2[result_df2['cluster']==8]

# %%
#get random data from each product category (change variable before .sample and name of json-file depending on category)
sampledata = laptop_stickers.sample(n=50, random_state=1)

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('laptop_stickers_sample.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in Laptop_sleeves_cases.iterrows()],indent=4)

with open('Laptop_sleeves_cases.json', 'w') as outfile:
    outfile.write(json_object)  

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_backpacks.iterrows()],indent=4)

with open('laptop_backpacks.json', 'w') as outfile:
    outfile.write(json_object)    

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in keyboard_protectors.iterrows()],indent=4)

with open('keyboard_protectors.json', 'w') as outfile:
    outfile.write(json_object)   
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_bags.iterrows()],indent=4)

with open('laptop_bags.json', 'w') as outfile:
    outfile.write(json_object)   
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_adapters_chargers.iterrows()],indent=4)

with open('laptop_adapters_chargers.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_batteries.iterrows()],indent=4)

with open('laptop_batteries.json', 'w') as outfile:
    outfile.write(json_object)  
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in laptop_stickers.iterrows()],indent=4)

with open('laptop_stickers.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#second iteration cluster 16

#vectorize cleaned text
vectorizer2 = TfidfVectorizer()
cluster16 = product_names[product_names['clusters']==16]
text_vec2 = vectorizer2.fit_transform(cluster16['cleaned'])

#show size of cleaned text
text_vec2.shape

#apply KMeans: select number of clusters 
kmeans2 = KMeans(n_clusters=10, random_state=0).fit(text_vec2)

#add clusters to original data
cluster16['cluster'] = kmeans2.labels_


#show product_names to see added clusters column
cluster16.head()
# Out:
# <ipython-input-127-0afa8a6ef019>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster16['cluster'] = kmeans2.labels_
#                                           product_name  \
# 56   8 PC Close Up Set : 55mm and 58mm Close-Up Fil...
# 186  JJC RR-SM 55MM Reverse Ring for 55MM Thread wi...
# 340  Crazepony FPV CCD Camera Lens 2.5mm Wide Angle...
# 375  Fotasy MC72 72 mm Metal Screw-in Lens Cap (Black)
# 493                         Tiffen 55mm Haze-2A Filter
#
#                                                cleaned  clusters  cluster
# 56   pc close up set mm mm close up filter set diop...        16        1
# 186  jjc rr sm mm revers ring mm thread soni nex ca...        16        9
# 340  crazeponi fpv ccd camera len mm wide angl degr...        16        3
# 375             fotasi mc mm metal screw len cap black        16        3
# 493                            tiffen mm haze a filter        16        8

# %%
cluster16.groupby(by=["cluster"]).size()
# Out:
# cluster
# 0    39
# 1    23
# 2    30
# 3    12
# 4    13
# 5     8
# 6     7
# 7    11
# 8    17
# 9    13
# dtype: int64

# %%
#add clusters to original data
result_df2 = pd.merge(data, cluster16[['product_name','cluster']], how='inner', on=["product_name"])

result_df2[result_df2.duplicated(subset=['product_url'])]

#drop duplicates
result_df2.drop_duplicates(subset=['product_url'],inplace=True)
result_df2.shape

#sort values by clusters
result_df2.sort_values(by=['cluster'],inplace=True)
result_df2.head()
# Out:
#                               uniq_id            crawl_timestamp        asin  \
# 86   07cdf002549b1dd231a03657c7195272  2020-02-06 18:19:44 +0000  B004GYXRM4
# 130  1fe4078dc8cd861472d91a23258d8ed0  2020-02-07 09:22:43 +0000  B01F1JJ5AA
# 128  5424341be5da6d37a95f187d2705a877  2020-02-07 09:22:44 +0000  B01C07F6SQ
# 126  8cde00e9eed2ea3d372fe311298fe972  2020-02-07 09:20:59 +0000  B07RZWP16K
# 76   9bbabed23cda48cddc73a890b0562b52  2020-02-07 05:32:35 +0000  B07B26QRGW
#
#                                            product_url  \
# 86   https://www.amazon.in/Polaroid-Multi-Coated-Va...
# 130  https://www.amazon.in/Gobe-ND1000-72mm-16-Laye...
# 128  https://www.amazon.in/Ozure-Neutral-Density-Fi...
# 126  https://www.amazon.in/Neewer-Compatible-Instal...
# 76   https://www.amazon.in/SHOPEE-Branded-Neutral-D...
#
#                                           product_name  \
# 86   Polaroid Optics 58mm HD Multi-Coated Variable ...
# 130            Gobe ND1000 72mm MRC 16-Layer ND Filter
# 128  Ozure Neutral Density Filters Kit (Set of Thre...
# 126  Neewer 3-Pack Filter Set Compatible with DJI O...
# 76              SHOPEE 58mm ND8 Neutral Density Filter
#
#                                      image_urls__small  \
# 86   https://images-na.ssl-images-amazon.com/images...
# 130  https://images-na.ssl-images-amazon.com/images...
# 128  https://images-na.ssl-images-amazon.com/images...
# 126  https://images-na.ssl-images-amazon.com/images...
# 76   https://images-na.ssl-images-amazon.com/images...
#
#                                                 medium  \
# 86   https://images-na.ssl-images-amazon.com/images...
# 130  https://images-na.ssl-images-amazon.com/images...
# 128  https://images-na.ssl-images-amazon.com/images...
# 126  https://images-na.ssl-images-amazon.com/images...
# 76   https://images-na.ssl-images-amazon.com/images...
#
#                                                  large  browsenode  \
# 86   https://images-na.ssl-images-amazon.com/images...  1389076031
# 130  https://images-na.ssl-images-amazon.com/images...  1389073031
# 128  https://images-na.ssl-images-amazon.com/images...  1389073031
# 126  https://images-na.ssl-images-amazon.com/images...  1389073031
# 76   https://images-na.ssl-images-amazon.com/images...  1389078031
#
#                 seller_name  ... no__of_sellers  \
# 86                    G. G.  ...            4.0
# 130          Cart2India SLP  ...            NaN
# 128                jumaanji  ...            NaN
# 126                     NaN  ...            NaN
# 76   aggarwal enterprises25  ...            NaN
#
#          sales_rank_in_child_category  \
# 86   {'NeutralDensityFilters': '#42'}
# 130                               NaN
# 128                               NaN
# 126                               NaN
# 76                                NaN
#
#                             product_details__k_v_pairs Number_Of_Items  \
# 86   {'Product_Dimensions': '5.8 x 5.8 x 1 cm ; 27....             NaN
# 130                                                NaN             NaN
# 128                                                NaN             NaN
# 126                                                NaN             NaN
# 76                                                 NaN             NaN
#
#     Batteries_Included  Batteries_Required Material Form_Factor left_in_stock  \
# 86                 NaN                 NaN      NaN         NaN           NaN
# 130                NaN                 NaN      NaN         NaN           NaN
# 128                NaN                 NaN      NaN         NaN           NaN
# 126                NaN                 NaN      NaN         NaN           NaN
# 76                 NaN                 NaN      NaN         NaN           NaN
#
#     cluster
# 86        0
# 130       0
# 128       0
# 126       0
# 76        0
#
# [5 rows x 37 columns]

# %%
#get random 7 products from cluster
sample_dataset_cluster16=result_df2.groupby("cluster").sample(n=7, random_state=1)

#save test/training data as json
json_object2 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster16.iterrows()],indent=4)

with open('sampledata_cluster16.json', 'w') as outfile:
    outfile.write(json_object2)

# %%
#Assigning clusters to product types according to the cluster analysis 
camera_filters = result_df2[result_df2['cluster'].isin([0,1,2,3,4,6,8])]
camera_lens_accessories = result_df2[result_df2['cluster'].isin([5,9])]
camera_filter_adapters = result_df2[result_df2['cluster']==7]

# %%
#get random data from each product category
sampledata = camera_filter_adapters.sample(n=10, random_state=1)
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('camera_filter_adapters_sample.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in camera_filters.iterrows()],indent=4)

with open('camera_filters.json', 'w') as outfile:
    outfile.write(json_object) 
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in camera_lens_accessories.iterrows()],indent=4)

with open('camera_lens_accessories.json', 'w') as outfile:
    outfile.write(json_object)  
    
#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in camera_filter_adapters.iterrows()],indent=4)

with open('camera_filter_adapters.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#second iteration cluster 18

#vectorize cleaned text
vectorizer2 = TfidfVectorizer()
cluster18 = product_names[product_names['clusters']==18]
text_vec2 = vectorizer2.fit_transform(cluster18['cleaned'])

#show size of cleaned text
text_vec2.shape

#apply KMeans: select number of clusters 
kmeans2 = KMeans(n_clusters=10, random_state=0).fit(text_vec2)

#add clusters to original data
cluster18['cluster'] = kmeans2.labels_


#show product_names to see added clusters column
cluster18.head()
# Out:
# <ipython-input-132-47e285129aa1>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster18['cluster'] = kmeans2.labels_
#                                           product_name  \
# 9    Verbatim Bravo Wired Notebook Optical Mouse, B...
# 14   Peace Hand - Gel Wrist Rest Support Mouse Pad ...
# 66   Non-Slip Round Mousepad, FINCIBO Unicorn Manda...
# 97   Arion Rapoo M10 2.4G Wireless Mouse With Nano ...
# 118  KiNGKANG watercolor vector pattern tropical ca...
#
#                                                cleaned  clusters  cluster
# 9        verbatim bravo wire notebook optic mous black        18        2
# 14   peac hand gel wrist rest support mous pad non ...        18        4
# 66   non slip round mousepad fincibo unicorn mandal...        18        1
# 97   arion rapoo m g wireless mous with nano receiv...        18        5
# 118  kingkang watercolor vector pattern tropic cact...        18        1

# %%
cluster18.groupby(by=["cluster"]).size()
# Out:
# cluster
# 0     4
# 1    50
# 2    37
# 3    40
# 4    17
# 5    26
# 6    19
# 7    10
# 8    18
# 9    16
# dtype: int64

# %%
#add clusters to original data
result_df2 = pd.merge(data, cluster18[['product_name','cluster']], how='inner', on=["product_name"])

result_df2[result_df2.duplicated(subset=['product_url'])]

#drop duplicates
result_df2.drop_duplicates(subset=['product_url'],inplace=True)
result_df2.shape

#sort values by clusters
result_df2.sort_values(by=['cluster'],inplace=True)
result_df2.head()
# Out:
#                               uniq_id            crawl_timestamp        asin  \
# 186  566e3f13f0f0316c5ee6fb871da6a398  2020-02-06 18:22:20 +0000  B014WZN6YA
# 197  bb72a9a403e4f744400f33f1a896d6f2  2020-02-06 20:26:18 +0000  B00CBH2KYO
# 7    fb2d010c3d561858d116fac0e9ee7509  2020-02-06 20:26:18 +0000  B00EKKIDPK
# 172  afc57138e73e042a8abb1c2d11234508  2020-02-06 20:06:15 +0000  B00JMK6U9Y
# 96   8531dd956e7a53ba2f234304db64d8f3  2020-02-06 17:55:01 +0000  B07DKZWN5N
#
#                                            product_url  \
# 186  https://www.amazon.in/William-Morris-Strawberr...
# 197  https://www.amazon.in/3dRose-LLC-Inches-Nursin...
# 7    https://www.amazon.in/Medieval-Offbeat-Unusual...
# 172  https://www.amazon.in/3dRose-Crazy-Ferret-Mous...
# 96   https://www.amazon.in/Marvo-G15-Gaming-Mousepa...
#
#                                           product_name  \
# 186  William Morris Strawberry Thief Pattern - Mous...
# 197  3dRose LLC 8 X 8 X 0.25 Inches Be Nice...Nurse...
# 7    3dRose LLC 8 x 8 x 0.25 Inches Mouse Pad, Wood...
# 172   3dRose Crazy Ferret Lady Mouse Pad (mp_175041_1)
# 96                    Marvo G15 Gaming Mousepad (Blue)
#
#                                      image_urls__small  \
# 186  https://images-na.ssl-images-amazon.com/images...
# 197  https://images-na.ssl-images-amazon.com/images...
# 7    https://images-na.ssl-images-amazon.com/images...
# 172  https://images-na.ssl-images-amazon.com/images...
# 96   https://images-na.ssl-images-amazon.com/images...
#
#                                                 medium  \
# 186  https://images-na.ssl-images-amazon.com/images...
# 197  https://images-na.ssl-images-amazon.com/images...
# 7    https://images-na.ssl-images-amazon.com/images...
# 172  https://images-na.ssl-images-amazon.com/images...
# 96   https://images-na.ssl-images-amazon.com/images...
#
#                                                  large  browsenode  \
# 186  https://images-na.ssl-images-amazon.com/images...  1375297031
# 197  https://images-na.ssl-images-amazon.com/images...  1375297031
# 7    https://images-na.ssl-images-amazon.com/images...  1375297031
# 172  https://images-na.ssl-images-amazon.com/images...  1375297031
# 96   https://images-na.ssl-images-amazon.com/images...  1375420031
#
#                     seller_name  ... no__of_sellers  \
# 186                Global Klamp  ...            NaN
# 197                Global Klamp  ...            NaN
# 7             Cart2India Online  ...            NaN
# 172                Global Klamp  ...            NaN
# 96   Appario Retail Private Ltd  ...            NaN
#
#     sales_rank_in_child_category  product_details__k_v_pairs Number_Of_Items  \
# 186                          NaN                         NaN             NaN
# 197                          NaN                         NaN             NaN
# 7                            NaN                         NaN             NaN
# 172                          NaN                         NaN             NaN
# 96                           NaN                         NaN             NaN
#
#     Batteries_Included  Batteries_Required Material Form_Factor left_in_stock  \
# 186                NaN                 NaN      NaN         NaN           NaN
# 197                NaN                 NaN      NaN         NaN           NaN
# 7                  NaN                 NaN      NaN         NaN           NaN
# 172                NaN                 NaN      NaN         NaN           NaN
# 96                 NaN                 NaN      NaN         NaN           NaN
#
#     cluster
# 186       0
# 197       0
# 7         0
# 172       0
# 96        1
#
# [5 rows x 37 columns]

# %%
#get random 4 products from cluster
sample_dataset_cluster_18 = result_df2.groupby("cluster").sample(n=4, random_state=1)

#save test/training data as json
json_object2 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster_18.iterrows()],indent=4)

with open('sampledata_cluster_18.json', 'w') as outfile:
    outfile.write(json_object2)

# %%
#third iteration: cluster 7_0
#vectorize cleaned text
vectorizer3 = TfidfVectorizer()
cluster7_0 = cluster7[cluster7['cluster']==0]

text_vec3 = vectorizer3.fit_transform(cluster7_0['cleaned'])

#apply KMeans: select number of clusters 
kmeans3 = KMeans(n_clusters=3, random_state=0).fit(text_vec3)

#add clusters to original data
cluster7_0['cluster2'] = kmeans3.labels_


#show product_names to see added clusters column
cluster7_0.head()
# Out:
# <ipython-input-191-e7160c57d103>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster7_0['cluster2'] = kmeans3.labels_
#                                           product_name  \
# 4    Redgear MPR800 Soft Base Mousepad with 4 LED S...
# 22   LuMee Two for iPhone 8/7/6s/6, The and Authent...
# 36   Incase ICON Case for iPhone 7 (Anthracite - IN...
# 80     SellZone Speaker for Dell Vostro 3560 P/N CCKFF
# 101  Zalman Optimized Vent Hole Ultra Quiet Noteboo...
#
#                                                cleaned  clusters  cluster  \
# 4     redgear mpr soft base mousepad led spectrum mode         7        0
# 22   lume two iphon the authent patent protect self...         7        0
# 36            incas icon case iphon anthracit inph ant         7        0
# 80               sellzon speaker dell vostro p n cckff         7        0
# 101  zalman optim vent hole ultra quiet notebook co...         7        0
#
#      cluster2
# 4           0
# 22          0
# 36          0
# 80          0
# 101         0

# %%
cluster7_0.groupby(by=["cluster2"]).size()
# Out:
# cluster2
# 0    370
# 1     90
# 2     37
# dtype: int64

# %%
#add clusters to original data
result_df3 = pd.merge(data, cluster7_0[['product_name','cluster2']], how='inner', on=["product_name"])

result_df3[result_df3.duplicated(subset=['product_url'])]

#drop duplicates
result_df3.drop_duplicates(subset=['product_url'],inplace=True)
result_df3.shape

#sort values by clusters
result_df3.sort_values(by=['cluster2'],inplace=True)
result_df3.head()

#get random 20 products from each cluster
sample_dataset_cluster7_0=result_df3.groupby("cluster2").sample(n=20, random_state=1)

# %%
#save test/training data as json
json_object3 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster7_0.iterrows()],indent=4)

with open('sampledata_cluster7_0.json', 'w') as outfile:
    outfile.write(json_object3)

# %%
non_fitting_products = result_df3[result_df3['cluster2'].isin([0,1,2])]

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in non_fitting_products.iterrows()],indent=4)

with open('non_fitting_products.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#get random data from each product category
sampledata = non_fitting_products.sample(n=200, random_state=1)

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('non_fitting_products_sample.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#third iteration: cluster 7_3
#vectorize cleaned text
vectorizer3 = TfidfVectorizer()
cluster7_3 = cluster7[cluster7['cluster']==3]

text_vec3 = vectorizer3.fit_transform(cluster7_3['cleaned'])

#apply KMeans: select number of clusters 
kmeans3 = KMeans(n_clusters=5, random_state=0).fit(text_vec3)

#add clusters to original data
cluster7_3['cluster2'] = kmeans3.labels_


#show product_names to see added clusters column
cluster7_3.head()
# Out:
# <ipython-input-197-b5a1f3c315e3>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster7_3['cluster2'] = kmeans3.labels_
#                                           product_name  \
# 55   TRIPP LITE 10 Gb/100 Gb Duplex Multimode 50/12...
# 95   Cable Matters 501101x7 Closed Screw Banana Plu...
# 146  Cellphonez Earphone Pouch - Multi Purpose Pock...
# 196  ABC Products® USB Cable Cord Lead for Sony Alp...
# 241  uxcell 100pcs 5A Copper Ring Terminals Lug Bat...
#
#                                                cleaned  clusters  cluster  \
# 55   tripp lite gb gb duplex multimod om lszh fiber...         7        3
# 95          cabl matter x close screw banana plug pair         7        3
# 146  cellphonez earphon pouch multi purpos pocket s...         7        3
# 196  abc product usb cabl cord lead soni alpha d sl...         7        3
# 241  uxcel pcs a copper ring termin lug batteri cab...         7        3
#
#      cluster2
# 55          2
# 95          2
# 146         3
# 196         0
# 241         2

# %%
cluster7_3.groupby(by=["cluster2"]).size()
# Out:
# cluster2
# 0    26
# 1    30
# 2    26
# 3    15
# 4    23
# dtype: int64

# %%
#add clusters to original data
result_df3 = pd.merge(data, cluster7_3[['product_name','cluster2']], how='inner', on=["product_name"])

result_df3[result_df3.duplicated(subset=['product_url'])]

#drop duplicates
result_df3.drop_duplicates(subset=['product_url'],inplace=True)
result_df3.shape

#sort values by clusters
result_df3.sort_values(by=['cluster2'],inplace=True)
result_df3.head()

#get random 20 products from each cluster
sample_dataset_cluster7_3=result_df3.groupby("cluster2").sample(n=15, random_state=1)

# %%
#save test/training data as json
json_object3 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster7_3.iterrows()],indent=4)

with open('sampledata_cluster7_3.json', 'w') as outfile:
    outfile.write(json_object3)

# %%
power_supplies = result_df3[result_df3['cluster2'].isin([0,1,2,3,4])]

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in power_supplies.iterrows()],indent=4)

with open('power_supplies.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#get random data from each product category
sampledata = power_supplies.sample(n=120, random_state=1)

#save file with all selected clusters as json
json_object = json.dumps([row.dropna().to_dict() for index,row in sampledata.iterrows()],indent=4)

with open('power_supplies_sample2.json', 'w') as outfile:
    outfile.write(json_object)

# %%
#third iteration: cluster 7_19
#vectorize cleaned text
vectorizer3 = TfidfVectorizer()
cluster7_19 = cluster7[cluster7['cluster']==19]

text_vec3 = vectorizer3.fit_transform(cluster7_19['cleaned'])

#apply KMeans: select number of clusters 
kmeans3 = KMeans(n_clusters=3, random_state=0).fit(text_vec3)

#add clusters to original data
cluster7_19['cluster2'] = kmeans3.labels_


#show product_names to see added clusters column
cluster7_19.head()
# Out:
# <ipython-input-69-1a9cd3874fc7>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cluster7_19['cluster2'] = kmeans3.labels_
#                                            product_name  \
# 32    Impossible PRD3107 Color Film for Polaroid Sx-...
# 192   Kastar NB-6L Battery (3-Pack) for Canon PowerS...
# 708   VKO Camera Shoulder Neck Strap for Fujifilm X-...
# 1039  Vivitar NB-10L Ultra High Capacity 1300mAh Li-...
# 1058  Nexme Red & Black Flower Designer 3D Mobile Co...
#
#                                                 cleaned  clusters  cluster  \
# 32             imposs prd color film polaroid sx camera         7       19
# 192   kastar nb l batteri pack canon powershot d d e...         7       19
# 708   vko camera shoulder neck strap fujifilm x t x ...         7       19
# 1039  vivitar nb l ultra high capac mah li ion batte...         7       19
# 1058  nexm red black flower design d mobil cover nok...         7       19
#
#       cluster2
# 32           2
# 192          2
# 708          2
# 1039         1
# 1058         0

# %%
cluster7_19.groupby(by=["cluster2"]).size()
# Out:
# cluster2
# 0    11
# 1     4
# 2     9
# dtype: int64

# %%
#add clusters to original data
result_df3 = pd.merge(data, cluster7_19[['product_name','cluster2']], how='inner', on=["product_name"])

result_df3[result_df3.duplicated(subset=['product_url'])]

#drop duplicates
result_df3.drop_duplicates(subset=['product_url'],inplace=True)
result_df3.shape

#sort values by clusters
result_df3.sort_values(by=['cluster2'],inplace=True)
result_df3.head()

#get random 20 products from each cluster
sample_dataset_cluster7_19=result_df3.groupby("cluster2").sample(n=4, random_state=1)

#save test/training data as json
json_object3 = json.dumps([row.dropna().to_dict() for index,row in sample_dataset_cluster7_19.iterrows()],indent=4)

with open('sampledata_cluster7_19.json', 'w') as outfile:
    outfile.write(json_object3)
